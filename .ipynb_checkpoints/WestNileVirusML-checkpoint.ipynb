# %%
import sys
import pandas as pd
import matplotlib
import numpy as np
import scipy as sp
import IPython
import sklearn
import random
import time
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.utils import resample
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.tools.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8

# %%
train_data = pd.read_csv('./input/train.csv')
test_data = pd.read_csv('./input/test.csv')
train_data_copy = train_data.copy(deep = True)
data_cleaner = [train_data_copy, test_data]
print (train_data.info())
train_data.sample(10)

#critical af variables:
# SPECIES, LOCATION, AND TIME are explanatory variables
# WNVPRESENT is the response variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 12 columns):
# Date                      10506 non-null object
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null object
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 985.0+ KB
# None
#              Date                                            Address  \
# 6399   2011-06-30    5800 North Pulaski Road, Chicago, IL 60646, USA
# 6048   2009-10-01  ORD Terminal 5, O'Hare International Airport, ...
# 10042  2013-09-06  1400 North Sacramento Avenue, Chicago, IL 6062...
# 3615   2007-10-04    2200 North Cannon Drive, Chicago, IL 60614, USA
# 1261   2007-08-01        South Stony Island Avenue, Chicago, IL, USA
# 1515   2007-08-07  3600 North Pittsburgh Avenue, Chicago, IL 6063...
# 172    2007-06-29           South Vincennes Avenue, Chicago, IL, USA
# 951    2007-08-01  7000 West Armitage Avenue, Chicago, IL 60707, USA
# 7461   2011-08-19  1700 North Ashland Avenue, Chicago, IL 60622, USA
# 9587   2013-08-15                                   Chicago, IL, USA
#
#                       Species  Block                   Street  Trap  \
# 6399          CULEX TERRITANS     58             N PULASKI RD  T027
# 6048           CULEX RESTUANS     10          W OHARE AIRPORT  T900
# 10042  CULEX PIPIENS/RESTUANS     14            N HUMBOLDT DR  T033
# 3615   CULEX PIPIENS/RESTUANS     22              N CANNON DR  T054
# 1261            CULEX PIPIENS     10       S STONY ISLAND AVE  T138
# 1515   CULEX PIPIENS/RESTUANS     36         N PITTSBURGH AVE  T011
# 172            CULEX RESTUANS     10              S VINCENNES  T089
# 951             CULEX PIPIENS     70        W ARMITAGE AVENUE  T151
# 7461           CULEX RESTUANS     17            N ASHLAND AVE  T232
# 9587           CULEX RESTUANS     43   N ASHLAND AVE OVERPASS  T145
#
#                           AddressNumberAndStreet   Latitude  Longitude  \
# 6399             5800  N PULASKI RD, Chicago, IL  41.984809 -87.728492
# 6048          1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 10042           1400  N HUMBOLDT DR, Chicago, IL  41.906638 -87.701431
# 3615              2200  N CANNON DR, Chicago, IL  41.921965 -87.632085
# 1261       1000  S STONY ISLAND AVE, Chicago, IL  41.726465 -87.585413
# 1515         3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
# 172               1000  S VINCENNES, Chicago, IL  41.723195 -87.649970
# 951        7000   W ARMITAGE AVENUE, Chicago, IL  41.916265 -87.800515
# 7461            1700  N ASHLAND AVE, Chicago, IL  41.912563 -87.668055
# 9587   4300  N ASHLAND AVE OVERPASS, Chicago, IL  41.878114 -87.629798
#
#        AddressAccuracy  NumMosquitos  WnvPresent
# 6399                 8             6           0
# 6048                 9             1           0
# 10042                9            27           0
# 3615                 8             2           0
# 1261                 5            50           0
# 1515                 8            28           1
# 172                  5             2           0
# 951                  8             8           0
# 7461                 9             2           0
# 9587                 3             1           0

# %%
print ('Train columns with null values:\n', train_data_copy.isnull().sum())
print ("-"*10)

print ('Test/Validation columns with null values:\n', test_data.isnull().sum())
print ("-"*10)

test_data.describe(include = 'all')
# Out:
# Train columns with null values:
#  Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64
# ----------
# Test/Validation columns with null values:
#  Id                        0
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# dtype: int64
# ----------
#                    Id        Date  \
# count   116293.000000      116293
# unique            NaN          95
# top               NaN  2012-07-09
# freq              NaN        1293
# mean     58147.000000         NaN
# std      33571.041765         NaN
# min          1.000000         NaN
# 25%      29074.000000         NaN
# 50%      58147.000000         NaN
# 75%      87220.000000         NaN
# max     116293.000000         NaN
#
#                                                   Address  \
# count                                              116293
# unique                                                151
# top     ORD Terminal 5, O'Hare International Airport, ...
# freq                                                 1468
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        Species          Block           Street    Trap  \
# count                   116293  116293.000000           116293  116293
# unique                       8            NaN              139     149
# top     CULEX PIPIENS/RESTUANS            NaN   N OAK PARK AVE    T009
# freq                     15359            NaN             1617    1528
# mean                       NaN      41.131100              NaN     NaN
# std                        NaN      24.864726              NaN     NaN
# min                        NaN      10.000000              NaN     NaN
# 25%                        NaN      18.000000              NaN     NaN
# 50%                        NaN      39.000000              NaN     NaN
# 75%                        NaN      61.000000              NaN     NaN
# max                        NaN      98.000000              NaN     NaN
#
#                     AddressNumberAndStreet       Latitude      Longitude  \
# count                               116293  116293.000000  116293.000000
# unique                                 151            NaN            NaN
# top     1000  W OHARE AIRPORT, Chicago, IL            NaN            NaN
# freq                                  1468            NaN            NaN
# mean                                   NaN      41.849389     -87.693658
# std                                    NaN       0.106593       0.080699
# min                                    NaN      41.644612     -87.930995
# 25%                                    NaN      41.753411     -87.750938
# 50%                                    NaN      41.862292     -87.694991
# 75%                                    NaN      41.951866     -87.648860
# max                                    NaN      42.017430     -87.531635
#
#         AddressAccuracy
# count     116293.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           7.954357
# std            1.252733
# min            3.000000
# 25%            8.000000
# 50%            8.000000
# 75%            9.000000
# max            9.000000

# %%
label = LabelEncoder()
for dataset in data_cleaner:
  #SPECIES
  dataset['Species_Code'] = label.fit_transform(dataset['Species'])

  #LOCATION
  dataset['LatBin'] = pd.cut(dataset['Latitude'], 10)
  dataset['LatBin_Code'] = label.fit_transform(dataset['LatBin'])
  dataset['LongBin'] = pd.cut(dataset['Longitude'], 10)
  dataset['LongBin_Code'] = label.fit_transform(dataset['LongBin'])

  dataset['AddressNum'] = [my_str.split(" ")[0] for my_str in dataset['AddressNumberAndStreet'].values]
  dataset['AddressNum'] = dataset['AddressNum'].convert_objects(convert_numeric = True)
  dataset['AddressNumBin'] = pd.cut(dataset['AddressNum'], 10)
  dataset['AddressNumBin_Code'] = label.fit_transform(dataset['AddressNumBin'])

###
#VER. 2
#North: x > 41.875
#Center: 41.81 < x < 41.875
#South: x < 41.81

#  dataset['Location'] = 'North'
#  dataset.loc[(dataset['Latitude'] < 41.875) & (dataset['Latitude'] > 41.81), 'Location'] = 'Center'
#  dataset.loc[dataset['Latitude'] < 41.81, 'Location'] = 'South'
#  dataset['Location_Code'] = 2
#  dataset.loc[(dataset['Latitude'] < 41.875) & (dataset['Latitude'] > 41.81), 'Location_Code'] = 1
#  dataset.loc[dataset['Latitude'] < 41.81, 'Location_Code'] = 0
###

###
#VER. 1
#  dataset['Location'] = 'North'
#  dataset.loc[dataset['Latitude'] < 41.83, 'Location'] = 'South'
#  dataset['Location_Code'] = 1
#  dataset.loc[dataset['Latitude'] < 41.83, 'Location_Code'] = 0
###

  #TIME
  dataset['Year'] = [my_str.split("-")[0] for my_str in dataset['Date'].values]
  dataset['Year'] = dataset['Year'].convert_objects(convert_numeric = True)
  dataset['Month'] = [my_str.split("-")[1] for my_str in dataset['Date'].values]
  dataset['Month'] = dataset['Month'].convert_objects(convert_numeric = True)
    
  #MISC.
  dataset['TrapNum'] = [my_str.split("T")[1] for my_str in dataset['Trap'].values]
  dataset['TrapNum'] = dataset['TrapNum'].convert_objects(convert_numeric = True)
  dataset['TrapNumBin'] = pd.cut(dataset['TrapNum'], 10)
  #dataset['TrapNumBin_Code'] = label.fit_transform(dataset['TrapNumBin'])
  ###DIS SHIT NEED TO BE FIXED ASAP
  dataset['TrapNumBin_Code'] = 0
  dataset.loc[(dataset['TrapNum'] > 91.2) & (dataset['TrapNum'] < 181.4), 'TrapNumBin_Code'] = 1
  dataset.loc[(dataset['TrapNum'] > 181.4) & (dataset['TrapNum'] < 271.6), 'TrapNumBin_Code'] = 2
  dataset.loc[(dataset['TrapNum'] > 812.8) & (dataset['TrapNum'] < 903.0), 'TrapNumBin_Code'] = 3
    

train_data_copy.info()
test_data.info()
train_data_copy.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10506 entries, 0 to 10505
# Data columns (total 25 columns):
# Date                      10506 non-null object
# Address                   10506 non-null object
# Species                   10506 non-null object
# Block                     10506 non-null int64
# Street                    10506 non-null object
# Trap                      10506 non-null object
# AddressNumberAndStreet    10506 non-null object
# Latitude                  10506 non-null float64
# Longitude                 10506 non-null float64
# AddressAccuracy           10506 non-null int64
# NumMosquitos              10506 non-null int64
# WnvPresent                10506 non-null int64
# Species_Code              10506 non-null int64
# LatBin                    10506 non-null category
# LatBin_Code               10506 non-null int64
# LongBin                   10506 non-null category
# LongBin_Code              10506 non-null int64
# AddressNum                10506 non-null int64
# AddressNumBin             10506 non-null category
# AddressNumBin_Code        10506 non-null int64
# Year                      10506 non-null int64
# Month                     10506 non-null int64
# TrapNum                   10492 non-null float64
# TrapNumBin                10492 non-null category
# TrapNumBin_Code           10506 non-null int64
# dtypes: category(4), float64(3), int64(12), object(6)
# memory usage: 1.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116293 entries, 0 to 116292
# Data columns (total 24 columns):
# Id                        116293 non-null int64
# Date                      116293 non-null object
# Address                   116293 non-null object
# Species                   116293 non-null object
# Block                     116293 non-null int64
# Street                    116293 non-null object
# Trap                      116293 non-null object
# AddressNumberAndStreet    116293 non-null object
# Latitude                  116293 non-null float64
# Longitude                 116293 non-null float64
# AddressAccuracy           116293 non-null int64
# Species_Code              116293 non-null int64
# LatBin                    116293 non-null category
# LatBin_Code               116293 non-null int64
# LongBin                   116293 non-null category
# LongBin_Code              116293 non-null int64
# AddressNum                116293 non-null int64
# AddressNumBin             116293 non-null category
# AddressNumBin_Code        116293 non-null int64
# Year                      116293 non-null int64
# Month                     116293 non-null int64
# TrapNum                   105628 non-null float64
# TrapNumBin                105628 non-null category
# TrapNumBin_Code           116293 non-null int64
# dtypes: category(4), float64(3), int64(11), object(6)
# memory usage: 18.2+ MB
#             Date                                            Address  \
# 2617  2007-08-24    6800 West Belden Avenue, Chicago, IL 60707, USA
# 1936  2007-08-15  1000 North Central Park Avenue, Chicago, IL 60...
# 7560  2011-08-26                  East 91st Place, Chicago, IL, USA
# 1908  2007-08-15  2700 South Western Avenue, Chicago, IL 60608, USA
# 5283  2009-08-07      6300 West 64th Street, Chicago, IL 60638, USA
# 9494  2013-08-08     2400 East 105th Street, Chicago, IL 60617, USA
# 4427  2009-06-29  ORD Terminal 5, O'Hare International Airport, ...
# 3227  2007-09-18  5000 South Central Avenue, Chicago, IL 60638, USA
# 1305  2007-08-01             South Avenue L, Chicago, IL 60617, USA
# 853   2007-08-01   7500 North Oakley Avenue, Chicago, IL 60645, USA
#
#                      Species  Block              Street  Trap  \
# 2617           CULEX PIPIENS     68        W BELDEN AVE  T037
# 1936           CULEX PIPIENS     10   N CENTRAL PARK DR  T030
# 7560  CULEX PIPIENS/RESTUANS     65           E 91ST PL  T227
# 1908           CULEX PIPIENS     27       S WESTERN AVE  T034
# 5283           CULEX PIPIENS     63           W 64TH ST  T155
# 9494  CULEX PIPIENS/RESTUANS     24          E 105TH ST  T128
# 4427  CULEX PIPIENS/RESTUANS     10     W OHARE AIRPORT  T900
# 3227           CULEX PIPIENS     50       S CENTRAL AVE  T031
# 1305  CULEX PIPIENS/RESTUANS     11          S AVENUE L  T103
# 853   CULEX PIPIENS/RESTUANS     75        N OAKLEY AVE  T148
#
#                     AddressNumberAndStreet   Latitude  Longitude  \
# 2617       6800  W BELDEN AVE, Chicago, IL  41.921177 -87.795180
# 1936  1000  N CENTRAL PARK DR, Chicago, IL  41.899230 -87.716788
# 7560          6500  E 91ST PL, Chicago, IL  41.728495 -87.600963
# 1908      2700  S WESTERN AVE, Chicago, IL  41.843811 -87.686763
# 5283          6300  W 64TH ST, Chicago, IL  41.776156 -87.778927
# 9494         2400  E 105TH ST, Chicago, IL  41.704572 -87.565666
# 4427    1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 3227      5000  S CENTRAL AVE, Chicago, IL  41.801498 -87.763416
# 1305         1100  S AVENUE L, Chicago, IL  41.702724 -87.536497
# 853        7500  N OAKLEY AVE, Chicago, IL  42.017430 -87.687769
#
#       AddressAccuracy       ...                    LongBin  LongBin_Code  \
# 2617                8       ...         (-87.811, -87.771]             3
# 1936                9       ...         (-87.731, -87.691]             5
# 7560                5       ...         (-87.612, -87.572]             8
# 1908                9       ...         (-87.691, -87.651]             6
# 5283                9       ...         (-87.811, -87.771]             3
# 9494                8       ...         (-87.572, -87.532]             9
# 4427                9       ...         (-87.891, -87.851]             1
# 3227                9       ...         (-87.771, -87.731]             4
# 1305                5       ...         (-87.572, -87.532]             9
# 853                 8       ...         (-87.691, -87.651]             6
#
#       AddressNum     AddressNumBin  AddressNumBin_Code  Year  Month  TrapNum  \
# 2617        6800  (6280.0, 7160.0]                   6  2007      8     37.0
# 1936        1000   (991.2, 1880.0]                   0  2007      8     30.0
# 7560        6500  (6280.0, 7160.0]                   6  2011      8    227.0
# 1908        2700  (1880.0, 2760.0]                   1  2007      8     34.0
# 5283        6300  (6280.0, 7160.0]                   6  2009      8    155.0
# 9494        2400  (1880.0, 2760.0]                   1  2013      8    128.0
# 4427        1000   (991.2, 1880.0]                   0  2009      6    900.0
# 3227        5000  (4520.0, 5400.0]                   4  2007      9     31.0
# 1305        1100   (991.2, 1880.0]                   0  2007      8    103.0
# 853         7500  (7160.0, 8040.0]                   7  2007      8    148.0
#
#           TrapNumBin  TrapNumBin_Code
# 2617   (0.098, 91.2]                0
# 1936   (0.098, 91.2]                0
# 7560  (181.4, 271.6]                2
# 1908   (0.098, 91.2]                0
# 5283   (91.2, 181.4]                1
# 9494   (91.2, 181.4]                1
# 4427  (812.8, 903.0]                3
# 3227   (0.098, 91.2]                0
# 1305   (91.2, 181.4]                1
# 853    (91.2, 181.4]                1
#
# [10 rows x 25 columns]

# %%
### CHILLAX THIS IS A TEST PEOPLE
weather = pd.read_csv('./input/weather.csv')
train_data_copy = train_data_copy.merge(weather)
test_data = test_data.merge(weather)
#for dataset in data_cleaner:
#  dataset['TminBin'] = pd.cut(dataset['Tmin'], 5)
#  dataset['DewPointBin'] = pd.cut(dataset['DewPoint'], 5)
print (train_data_copy.info()) # last row index is 2943!
train_data_copy.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21012 entries, 0 to 21011
# Data columns (total 46 columns):
# Date                      21012 non-null object
# Address                   21012 non-null object
# Species                   21012 non-null object
# Block                     21012 non-null int64
# Street                    21012 non-null object
# Trap                      21012 non-null object
# AddressNumberAndStreet    21012 non-null object
# Latitude                  21012 non-null float64
# Longitude                 21012 non-null float64
# AddressAccuracy           21012 non-null int64
# NumMosquitos              21012 non-null int64
# WnvPresent                21012 non-null int64
# Species_Code              21012 non-null int64
# LatBin                    21012 non-null category
# LatBin_Code               21012 non-null int64
# LongBin                   21012 non-null category
# LongBin_Code              21012 non-null int64
# AddressNum                21012 non-null int64
# AddressNumBin             21012 non-null category
# AddressNumBin_Code        21012 non-null int64
# Year                      21012 non-null int64
# Month                     21012 non-null int64
# TrapNum                   20984 non-null float64
# TrapNumBin                20984 non-null category
# TrapNumBin_Code           21012 non-null int64
# Station                   21012 non-null int64
# Tmax                      21012 non-null int64
# Tmin                      21012 non-null int64
# Tavg                      21012 non-null object
# Depart                    21012 non-null object
# DewPoint                  21012 non-null int64
# WetBulb                   21012 non-null object
# Heat                      21012 non-null object
# Cool                      21012 non-null object
# Sunrise                   21012 non-null object
# Sunset                    21012 non-null object
# CodeSum                   21012 non-null object
# Depth                     21012 non-null object
# Water1                    21012 non-null object
# SnowFall                  21012 non-null object
# PrecipTotal               21012 non-null object
# StnPressure               21012 non-null object
# SeaLevel                  21012 non-null object
# ResultSpeed               21012 non-null float64
# ResultDir                 21012 non-null int64
# AvgSpeed                  21012 non-null object
# dtypes: category(4), float64(4), int64(17), object(21)
# memory usage: 7.0+ MB
# None
#              Date                                            Address  \
# 4923   2007-08-22  9300 South Doctor Martin Luther King Junior Dr...
# 10992  2009-08-25  3300 North Rutherford Avenue, Chicago, IL 6063...
# 479    2007-07-02  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 11103  2009-08-27  3600 North Pittsburgh Avenue, Chicago, IL 6063...
# 10711  2009-08-13  6000 West Montrose Avenue, Chicago, IL 60634, USA
# 9900   2009-07-24  5000 South Central Avenue, Chicago, IL 60638, USA
# 4085   2007-08-15             South Avenue L, Chicago, IL 60617, USA
# 16384  2013-06-14  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 8170   2009-06-12  1000 North Central Park Avenue, Chicago, IL 60...
# 10624  2009-08-07       South Brandon Avenue, Chicago, IL 60617, USA
#
#                       Species  Block                          Street  Trap  \
# 4923   CULEX PIPIENS/RESTUANS     93   S DR MARTIN LUTHER KING JR DR  T162
# 10992  CULEX PIPIENS/RESTUANS     33                N RUTHERFORD AVE  T144
# 479            CULEX RESTUANS     62                   N MANDELL AVE  T007
# 11103  CULEX PIPIENS/RESTUANS     36                N PITTSBURGH AVE  T011
# 10711  CULEX PIPIENS/RESTUANS     60                   W MONTROSE DR  T017
# 9900            CULEX PIPIENS     50                   S CENTRAL AVE  T031
# 4085            CULEX PIPIENS     11                      S AVENUE L  T103
# 16384          CULEX RESTUANS     41                  N OAK PARK AVE  T002
# 8170           CULEX RESTUANS     10               N CENTRAL PARK DR  T030
# 10624  CULEX PIPIENS/RESTUANS     13                       S BRANDON  T209
#
#                                  AddressNumberAndStreet   Latitude  Longitude  \
# 4923   9300  S DR MARTIN LUTHER KING JR DR, Chicago, IL  41.725517 -87.614258
# 10992               3300  N RUTHERFORD AVE, Chicago, IL  41.940160 -87.794896
# 479                    6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 11103               3600  N PITTSBURGH AVE, Chicago, IL  41.944869 -87.832763
# 10711                  6000  W MONTROSE DR, Chicago, IL  41.960616 -87.777189
# 9900                   5000  S CENTRAL AVE, Chicago, IL  41.801498 -87.763416
# 4085                      1100  S AVENUE L, Chicago, IL  41.702724 -87.536497
# 16384                 4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 8170               1000  N CENTRAL PARK DR, Chicago, IL  41.899230 -87.716788
# 10624                      1300  S BRANDON, Chicago, IL  41.740641 -87.546587
#
#        AddressAccuracy    ...           CodeSum  Depth  Water1 SnowFall  \
# 4923                 8    ...        TSRA RA BR      M       M        M
# 10992                9    ...                        M       M        M
# 479                  9    ...                        M       M        M
# 11103                8    ...             RA BR      M       M        M
# 10711                9    ...                        0       M      0.0
# 9900                 9    ...           TSRA RA      M       M        M
# 4085                 5    ...     TS TSRA RA BR      M       M        M
# 16384                9    ...                        0       M      0.0
# 8170                 9    ...                RA      0       M      0.0
# 10624                5    ...             RA BR      M       M        M
#
#        PrecipTotal StnPressure  SeaLevel  ResultSpeed ResultDir  AvgSpeed
# 4923          0.88       29.29     29.93          5.1        21       8.4
# 10992         0.00       29.39     30.04          8.3        21       8.6
# 479           0.00       29.55     30.21          7.4        12       8.5
# 11103         1.19       29.41     30.07         10.7         8      11.0
# 10711         0.00       29.38     30.10          1.5        14       3.8
# 9900          0.19       29.14     29.82          8.7        23       9.6
# 4085          0.83       29.23     29.87          4.9         6       7.1
# 16384         0.00       29.34     30.05          6.6         6       7.9
# 8170             T       29.24     29.95          4.4         7       5.8
# 10624         0.23       29.41     30.08          6.4        15       7.2
#
# [10 rows x 46 columns]

# %%
train_data_copy['WnvPresent'].hist()

# %%
df = train_data_copy
df['WnvPresent'].value_counts()
# Out:
# 0    19910
# 1     1102
# Name: WnvPresent, dtype: int64

# %%
df_majority = df[df.WnvPresent==0]
df_minority = df[df.WnvPresent==1]

df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=551,     # to match minority class
                                 random_state=123) # reproducible results

df_downsampled = pd.concat([df_majority_downsampled, df_minority])
df_downsampled.WnvPresent.value_counts()
train_data_copy = df_downsampled
train_data_copy.head()
# Out:
#              Date                                            Address  \
# 6495   2007-09-18  7000 North Moselle Avenue, Chicago, IL 60646, USA
# 14637  2011-08-12  ORD Terminal 5, O'Hare International Airport, ...
# 19346  2013-08-15  ORD Terminal 5, O'Hare International Airport, ...
# 14171  2011-08-05    2200 North Cannon Drive, Chicago, IL 60614, USA
# 7253   2007-10-04       North Streeter Drive, Chicago, IL 60611, USA
#
#                       Species  Block            Street  Trap  \
# 6495   CULEX PIPIENS/RESTUANS     70      N MOSELL AVE  T008
# 14637          CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 19346          CULEX RESTUANS     10   W OHARE AIRPORT  T900
# 14171  CULEX PIPIENS/RESTUANS     22       N CANNON DR  T054
# 7253   CULEX PIPIENS/RESTUANS     53     N STREETER DR  T129
#
#                    AddressNumberAndStreet   Latitude  Longitude  \
# 6495      7000  N MOSELL AVE, Chicago, IL  42.008314 -87.777921
# 14637  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 19346  1000  W OHARE AIRPORT, Chicago, IL  41.974689 -87.890615
# 14171      2200  N CANNON DR, Chicago, IL  41.921965 -87.632085
# 7253     5300  N STREETER DR, Chicago, IL  41.891126 -87.611560
#
#        AddressAccuracy    ...     CodeSum  Depth  Water1 SnowFall  \
# 6495                 9    ...                  M       M        M
# 14637                9    ...                  M       M        M
# 19346                9    ...                  0       M      0.0
# 14171                8    ...                  M       M        M
# 7253                 5    ...                  M       M        M
#
#        PrecipTotal StnPressure  SeaLevel  ResultSpeed ResultDir  AvgSpeed
# 6495          0.00       29.41     30.05         12.5        19      12.8
# 14637         0.00       29.28     29.93          8.2        19       8.4
# 19346         0.00       29.40     30.13          4.2        24       4.9
# 14171            T       29.26     29.91          5.2         7       6.0
# 7253          0.00       29.39     30.03          4.6        17       5.9
#
# [5 rows x 46 columns]

# %%
Target = ['WnvPresent']

train_data_copy_x = ['Species', 'LatBin', 'LongBin', 'AddressAccuracy', 'Year', 'Month', 'TrapNumBin', 'AddressNumBin', 'Tmin', 'DewPoint']
train_data_copy_x_calc = ['Species_Code', 'LatBin_Code', 'LongBin_Code', 'AddressAccuracy', 'Year', 'Month', 'TrapNumBin_Code', 'AddressNumBin_Code', 'Tmin', 'DewPoint']
train_data_copy_xy = Target + train_data_copy_x
print('So-Called Original X Y: ', train_data_copy_xy, '\n')

train_data_copy_x_bin = ['Species_Code', 'LatBin_Code', 'LongBin_Code', 'AddressAccuracy', 'Year', 'Month', 'TrapNumBin_Code', 'AddressNumBin_Code', 'Tmin', 'DewPoint']
train_data_copy_xy_bin = Target + train_data_copy_x_bin
print('Bin X Y: ', train_data_copy_xy_bin, '\n')

train_data_copy_dummy = pd.get_dummies(train_data_copy[train_data_copy_x])
train_data_copy_x_dummy = train_data_copy_dummy.columns.tolist()
train_data_copy_xy_dummy = Target + train_data_copy_x_dummy
print('Dummy X Y: ', train_data_copy_xy_dummy, '\n')

train_data_copy_dummy.head()
# Out:
# So-Called Original X Y:  ['WnvPresent', 'Species', 'LatBin', 'LongBin', 'AddressAccuracy', 'Year', 'Month', 'TrapNumBin', 'AddressNumBin', 'Tmin', 'DewPoint']
#
# Bin X Y:  ['WnvPresent', 'Species_Code', 'LatBin_Code', 'LongBin_Code', 'AddressAccuracy', 'Year', 'Month', 'TrapNumBin_Code', 'AddressNumBin_Code', 'Tmin', 'DewPoint']
#
# Dummy X Y:  ['WnvPresent', 'AddressAccuracy', 'Year', 'Month', 'Tmin', 'DewPoint', 'Species_CULEX PIPIENS', 'Species_CULEX PIPIENS/RESTUANS', 'Species_CULEX RESTUANS', 'Species_CULEX SALINARIUS', 'Species_CULEX TARSALIS', 'Species_CULEX TERRITANS', 'LatBin_(41.644, 41.682]', 'LatBin_(41.682, 41.719]', 'LatBin_(41.719, 41.756]', 'LatBin_(41.756, 41.794]', 'LatBin_(41.794, 41.831]', 'LatBin_(41.831, 41.868]', 'LatBin_(41.868, 41.906]', 'LatBin_(41.906, 41.943]', 'LatBin_(41.943, 41.98]', 'LatBin_(41.98, 42.017]', 'LongBin_(-87.931, -87.891]', 'LongBin_(-87.891, -87.851]', 'LongBin_(-87.851, -87.811]', 'LongBin_(-87.811, -87.771]', 'LongBin_(-87.771, -87.731]', 'LongBin_(-87.731, -87.691]', 'LongBin_(-87.691, -87.651]', 'LongBin_(-87.651, -87.612]', 'LongBin_(-87.612, -87.572]', 'LongBin_(-87.572, -87.532]', 'TrapNumBin_(0.098, 91.2]', 'TrapNumBin_(91.2, 181.4]', 'TrapNumBin_(181.4, 271.6]', 'TrapNumBin_(271.6, 361.8]', 'TrapNumBin_(361.8, 452.0]', 'TrapNumBin_(452.0, 542.2]', 'TrapNumBin_(542.2, 632.4]', 'TrapNumBin_(632.4, 722.6]', 'TrapNumBin_(722.6, 812.8]', 'TrapNumBin_(812.8, 903.0]', 'AddressNumBin_(991.2, 1880.0]', 'AddressNumBin_(1880.0, 2760.0]', 'AddressNumBin_(2760.0, 3640.0]', 'AddressNumBin_(3640.0, 4520.0]', 'AddressNumBin_(4520.0, 5400.0]', 'AddressNumBin_(5400.0, 6280.0]', 'AddressNumBin_(6280.0, 7160.0]', 'AddressNumBin_(7160.0, 8040.0]', 'AddressNumBin_(8040.0, 8920.0]', 'AddressNumBin_(8920.0, 9800.0]']
#        AddressAccuracy  Year  Month  Tmin  DewPoint  Species_CULEX PIPIENS  \
# 6495                 9  2007      9    66        57                      0
# 14637                9  2011      8    65        57                      0
# 19346                9  2013      8    55        53                      0
# 14171                8  2011      8    70        68                      0
# 7253                 5  2007     10    56        56                      0
#
#        Species_CULEX PIPIENS/RESTUANS  Species_CULEX RESTUANS  \
# 6495                                1                       0
# 14637                               0                       1
# 19346                               0                       1
# 14171                               1                       0
# 7253                                1                       0
#
#        Species_CULEX SALINARIUS  Species_CULEX TARSALIS  \
# 6495                          0                       0
# 14637                         0                       0
# 19346                         0                       0
# 14171                         0                       0
# 7253                          0                       0
#
#                     ...                AddressNumBin_(991.2, 1880.0]  \
# 6495                ...                                            0
# 14637               ...                                            1
# 19346               ...                                            1
# 14171               ...                                            0
# 7253                ...                                            0
#
#        AddressNumBin_(1880.0, 2760.0]  AddressNumBin_(2760.0, 3640.0]  \
# 6495                                0                               0
# 14637                               0                               0
# 19346                               0                               0
# 14171                               1                               0
# 7253                                0                               0
#
#        AddressNumBin_(3640.0, 4520.0]  AddressNumBin_(4520.0, 5400.0]  \
# 6495                                0                               0
# 14637                               0                               0
# 19346                               0                               0
# 14171                               0                               0
# 7253                                0                               1
#
#        AddressNumBin_(5400.0, 6280.0]  AddressNumBin_(6280.0, 7160.0]  \
# 6495                                0                               1
# 14637                               0                               0
# 19346                               0                               0
# 14171                               0                               0
# 7253                                0                               0
#
#        AddressNumBin_(7160.0, 8040.0]  AddressNumBin_(8040.0, 8920.0]  \
# 6495                                0                               0
# 14637                               0                               0
# 19346                               0                               0
# 14171                               0                               0
# 7253                                0                               0
#
#        AddressNumBin_(8920.0, 9800.0]
# 6495                                0
# 14637                               0
# 19346                               0
# 14171                               0
# 7253                                0
#
# [5 rows x 51 columns]

# %%
print('Train columns with null values: \n', train_data_copy.isnull().sum())
print("-"*10)
print (train_data_copy.info())
print("-"*10)

print('Test/Validation columns with null values: \n', test_data.isnull().sum())
print("-"*10)
print (test_data.info())
print("-"*10)

train_data.describe(include = 'all')
# Out:
# Train columns with null values:
#  Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# Species_Code              0
# LatBin                    0
# LatBin_Code               0
# LongBin                   0
# LongBin_Code              0
# AddressNum                0
# AddressNumBin             0
# AddressNumBin_Code        0
# Year                      0
# Month                     0
# TrapNum                   2
# TrapNumBin                2
# TrapNumBin_Code           0
# Station                   0
# Tmax                      0
# Tmin                      0
# Tavg                      0
# Depart                    0
# DewPoint                  0
# WetBulb                   0
# Heat                      0
# Cool                      0
# Sunrise                   0
# Sunset                    0
# CodeSum                   0
# Depth                     0
# Water1                    0
# SnowFall                  0
# PrecipTotal               0
# StnPressure               0
# SeaLevel                  0
# ResultSpeed               0
# ResultDir                 0
# AvgSpeed                  0
# dtype: int64
# ----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1653 entries, 6495 to 21003
# Data columns (total 46 columns):
# Date                      1653 non-null object
# Address                   1653 non-null object
# Species                   1653 non-null object
# Block                     1653 non-null int64
# Street                    1653 non-null object
# Trap                      1653 non-null object
# AddressNumberAndStreet    1653 non-null object
# Latitude                  1653 non-null float64
# Longitude                 1653 non-null float64
# AddressAccuracy           1653 non-null int64
# NumMosquitos              1653 non-null int64
# WnvPresent                1653 non-null int64
# Species_Code              1653 non-null int64
# LatBin                    1653 non-null category
# LatBin_Code               1653 non-null int64
# LongBin                   1653 non-null category
# LongBin_Code              1653 non-null int64
# AddressNum                1653 non-null int64
# AddressNumBin             1653 non-null category
# AddressNumBin_Code        1653 non-null int64
# Year                      1653 non-null int64
# Month                     1653 non-null int64
# TrapNum                   1651 non-null float64
# TrapNumBin                1651 non-null category
# TrapNumBin_Code           1653 non-null int64
# Station                   1653 non-null int64
# Tmax                      1653 non-null int64
# Tmin                      1653 non-null int64
# Tavg                      1653 non-null object
# Depart                    1653 non-null object
# DewPoint                  1653 non-null int64
# WetBulb                   1653 non-null object
# Heat                      1653 non-null object
# Cool                      1653 non-null object
# Sunrise                   1653 non-null object
# Sunset                    1653 non-null object
# CodeSum                   1653 non-null object
# Depth                     1653 non-null object
# Water1                    1653 non-null object
# SnowFall                  1653 non-null object
# PrecipTotal               1653 non-null object
# StnPressure               1653 non-null object
# SeaLevel                  1653 non-null object
# ResultSpeed               1653 non-null float64
# ResultDir                 1653 non-null int64
# AvgSpeed                  1653 non-null object
# dtypes: category(4), float64(4), int64(17), object(21)
# memory usage: 562.4+ KB
# None
# ----------
# Test/Validation columns with null values:
#  Id                            0
# Date                          0
# Address                       0
# Species                       0
# Block                         0
# Street                        0
# Trap                          0
# AddressNumberAndStreet        0
# Latitude                      0
# Longitude                     0
# AddressAccuracy               0
# Species_Code                  0
# LatBin                        0
# LatBin_Code                   0
# LongBin                       0
# LongBin_Code                  0
# AddressNum                    0
# AddressNumBin                 0
# AddressNumBin_Code            0
# Year                          0
# Month                         0
# TrapNum                   21330
# TrapNumBin                21330
# TrapNumBin_Code               0
# Station                       0
# Tmax                          0
# Tmin                          0
# Tavg                          0
# Depart                        0
# DewPoint                      0
# WetBulb                       0
# Heat                          0
# Cool                          0
# Sunrise                       0
# Sunset                        0
# CodeSum                       0
# Depth                         0
# Water1                        0
# SnowFall                      0
# PrecipTotal                   0
# StnPressure                   0
# SeaLevel                      0
# ResultSpeed                   0
# ResultDir                     0
# AvgSpeed                      0
# dtype: int64
# ----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 232586 entries, 0 to 232585
# Data columns (total 45 columns):
# Id                        232586 non-null int64
# Date                      232586 non-null object
# Address                   232586 non-null object
# Species                   232586 non-null object
# Block                     232586 non-null int64
# Street                    232586 non-null object
# Trap                      232586 non-null object
# AddressNumberAndStreet    232586 non-null object
# Latitude                  232586 non-null float64
# Longitude                 232586 non-null float64
# AddressAccuracy           232586 non-null int64
# Species_Code              232586 non-null int64
# LatBin                    232586 non-null category
# LatBin_Code               232586 non-null int64
# LongBin                   232586 non-null category
# LongBin_Code              232586 non-null int64
# AddressNum                232586 non-null int64
# AddressNumBin             232586 non-null category
# AddressNumBin_Code        232586 non-null int64
# Year                      232586 non-null int64
# Month                     232586 non-null int64
# TrapNum                   211256 non-null float64
# TrapNumBin                211256 non-null category
# TrapNumBin_Code           232586 non-null int64
# Station                   232586 non-null int64
# Tmax                      232586 non-null int64
# Tmin                      232586 non-null int64
# Tavg                      232586 non-null object
# Depart                    232586 non-null object
# DewPoint                  232586 non-null int64
# WetBulb                   232586 non-null object
# Heat                      232586 non-null object
# Cool                      232586 non-null object
# Sunrise                   232586 non-null object
# Sunset                    232586 non-null object
# CodeSum                   232586 non-null object
# Depth                     232586 non-null object
# Water1                    232586 non-null object
# SnowFall                  232586 non-null object
# PrecipTotal               232586 non-null object
# StnPressure               232586 non-null object
# SeaLevel                  232586 non-null object
# ResultSpeed               232586 non-null float64
# ResultDir                 232586 non-null int64
# AvgSpeed                  232586 non-null object
# dtypes: category(4), float64(4), int64(16), object(21)
# memory usage: 75.4+ MB
# None
# ----------
#               Date                                            Address  \
# count        10506                                              10506
# unique          95                                                138
# top     2007-08-01  ORD Terminal 5, O'Hare International Airport, ...
# freq           551                                                750
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#                        Species         Block            Street   Trap  \
# count                    10506  10506.000000             10506  10506
# unique                       7           NaN               128    136
# top     CULEX PIPIENS/RESTUANS           NaN   W OHARE AIRPORT   T900
# freq                      4752           NaN               750    750
# mean                       NaN     35.687797               NaN    NaN
# std                        NaN     24.339468               NaN    NaN
# min                        NaN     10.000000               NaN    NaN
# 25%                        NaN     12.000000               NaN    NaN
# 50%                        NaN     33.000000               NaN    NaN
# 75%                        NaN     52.000000               NaN    NaN
# max                        NaN     98.000000               NaN    NaN
#
#                     AddressNumberAndStreet      Latitude     Longitude  \
# count                                10506  10506.000000  10506.000000
# unique                                 138           NaN           NaN
# top     1000  W OHARE AIRPORT, Chicago, IL           NaN           NaN
# freq                                   750           NaN           NaN
# mean                                   NaN     41.841139    -87.699908
# std                                    NaN      0.112742      0.096514
# min                                    NaN     41.644612    -87.930995
# 25%                                    NaN     41.732984    -87.760070
# 50%                                    NaN     41.846283    -87.694991
# 75%                                    NaN     41.954690    -87.627796
# max                                    NaN     42.017430    -87.531635
#
#         AddressAccuracy  NumMosquitos    WnvPresent
# count      10506.000000  10506.000000  10506.000000
# unique              NaN           NaN           NaN
# top                 NaN           NaN           NaN
# freq                NaN           NaN           NaN
# mean           7.819532     12.853512      0.052446
# std            1.452921     16.133816      0.222936
# min            3.000000      1.000000      0.000000
# 25%            8.000000      2.000000      0.000000
# 50%            8.000000      5.000000      0.000000
# 75%            9.000000     17.000000      0.000000
# max            9.000000     50.000000      1.000000

# %%
train1_x, test1_x, train1_y, test1_y = model_selection.train_test_split(train_data_copy[train_data_copy_x_calc], train_data_copy[Target], random_state = 0)
train1_x_bin, test1_x_bin, train1_y_bin, test1_y_bin = model_selection.train_test_split(train_data_copy[train_data_copy_x_bin], train_data_copy[Target], random_state = 0)
train1_x_dummy, test1_x_dummy, train1_y_dummy, test1_y_dummy = model_selection.train_test_split(train_data_copy_dummy[train_data_copy_x_dummy], train_data_copy[Target], random_state = 0)

print("Train Data Copy Shape: {}".format(train_data_copy.shape))
print("Train1 Shape: {}".format(train1_x.shape))
print("Test1 Shape: {}".format(test1_x.shape))

train1_x_bin.head()
# Out:
# Train Data Copy Shape: (1653, 46)
# Train1 Shape: (1239, 10)
# Test1 Shape: (414, 10)
#        Species_Code  LatBin_Code  LongBin_Code  AddressAccuracy  Year  Month  \
# 20254             1            8             1                9  2013      9
# 3956              2            3             6                8  2007      8
# 10019             3            1             5                8  2009      7
# 20281             1            2             4                8  2013      9
# 15265             1            9             3                9  2011      9
#
#        TrapNumBin_Code  AddressNumBin_Code  Tmin  DewPoint
# 20254                3                   0    57        58
# 3956                 0                   1    71        67
# 10019                1                   2    66        61
# 20281                2                   8    62        55
# 15265                2                   6    74        70

# %%
for x in train_data_copy_x:
    if train_data_copy[x].dtype != 'float64':
        print('Virus Correlation by:', x)
        print(train_data_copy[[x, Target[0]]].groupby(x, as_index = False).mean())
        print('-'*10, '\n')
# Out:
# Virus Correlation by: Species
#                   Species  WnvPresent
# 0           CULEX PIPIENS    0.781759
# 1  CULEX PIPIENS/RESTUANS    0.675258
# 2          CULEX RESTUANS    0.406639
# 3        CULEX SALINARIUS    0.000000
# 4          CULEX TARSALIS    0.000000
# 5         CULEX TERRITANS    0.000000
# ----------
#
# Virus Correlation by: LatBin
#              LatBin  WnvPresent
# 0  (41.644, 41.682]    0.684783
# 1  (41.682, 41.719]    0.720721
# 2  (41.719, 41.756]    0.620000
# 3  (41.756, 41.794]    0.538462
# 4  (41.794, 41.831]    0.642336
# 5  (41.831, 41.868]    0.463415
# 6  (41.868, 41.906]    0.560000
# 7  (41.906, 41.943]    0.690141
# 8   (41.943, 41.98]    0.744417
# 9   (41.98, 42.017]    0.719577
# ----------
#
# Virus Correlation by: LongBin
#               LongBin  WnvPresent
# 0  (-87.931, -87.891]    0.666667
# 1  (-87.891, -87.851]    0.795580
# 2  (-87.851, -87.811]    0.833333
# 3  (-87.811, -87.771]    0.758621
# 4  (-87.771, -87.731]    0.696133
# 5  (-87.731, -87.691]    0.594378
# 6  (-87.691, -87.651]    0.567901
# 7  (-87.651, -87.612]    0.655462
# 8  (-87.612, -87.572]    0.629787
# 9  (-87.572, -87.532]    0.601626
# ----------
#
# Virus Correlation by: AddressAccuracy
#    AddressAccuracy  WnvPresent
# 0                3    0.250000
# 1                5    0.646048
# 2                8    0.675070
# 3                9    0.671875
# ----------
#
# Virus Correlation by: Year
#    Year  WnvPresent
# 0  2007    0.704478
# 1  2009    0.243590
# 2  2011    0.473029
# 3  2013    0.815700
# ----------
#
# Virus Correlation by: Month
#    Month  WnvPresent
# 0      5    0.000000
# 1      6    0.023256
# 2      7    0.380165
# 3      8    0.794521
# 4      9    0.710227
# 5     10    0.190476
# ----------
#
# Virus Correlation by: TrapNumBin
#        TrapNumBin  WnvPresent
# 0   (0.098, 91.2]    0.649573
# 1   (91.2, 181.4]    0.638211
# 2  (181.4, 271.6]    0.684615
# 3  (271.6, 361.8]         NaN
# 4  (361.8, 452.0]         NaN
# 5  (452.0, 542.2]         NaN
# 6  (542.2, 632.4]         NaN
# 7  (632.4, 722.6]         NaN
# 8  (722.6, 812.8]         NaN
# 9  (812.8, 903.0]    0.771574
# ----------
#
# Virus Correlation by: AddressNumBin
#       AddressNumBin  WnvPresent
# 0   (991.2, 1880.0]    0.651017
# 1  (1880.0, 2760.0]    0.638889
# 2  (2760.0, 3640.0]    0.652174
# 3  (3640.0, 4520.0]    0.666667
# 4  (4520.0, 5400.0]    0.718954
# 5  (5400.0, 6280.0]    0.694915
# 6  (6280.0, 7160.0]    0.706667
# 7  (7160.0, 8040.0]    0.615385
# 8  (8040.0, 8920.0]    0.692308
# 9  (8920.0, 9800.0]    0.651163
# ----------
#
# Virus Correlation by: Tmin
#     Tmin  WnvPresent
# 0     41    0.000000
# 1     44    0.000000
# 2     45    0.000000
# 3     46    0.541667
# 4     47    0.000000
# 5     48    0.535714
# 6     49    0.000000
# 7     50    0.235294
# 8     51    0.111111
# 9     52    0.000000
# 10    53    0.000000
# 11    54    0.000000
# 12    55    0.705882
# 13    56    0.250000
# 14    57    0.705128
# 15    58    0.317073
# 16    59    0.560000
# 17    60    0.557692
# 18    61    0.740260
# 19    62    0.763158
# 20    63    0.589286
# 21    64    0.461538
# 22    65    0.784091
# 23    66    0.735294
# 24    67    0.755556
# 25    68    0.618182
# 26    69    0.785515
# 27    70    0.626374
# 28    71    0.617391
# 29    72    0.810811
# 30    73    0.534483
# 31    74    0.700000
# 32    75    0.882353
# 33    76    0.750000
# 34    79    0.750000
# ----------
#
# Virus Correlation by: DewPoint
#     DewPoint  WnvPresent
# 0         38    0.375000
# 1         40    0.500000
# 2         41    0.000000
# 3         42    0.500000
# 4         43    0.500000
# 5         44    0.461538
# 6         45    0.000000
# 7         46    0.300000
# 8         47    0.000000
# 9         48    0.000000
# 10        49    0.000000
# 11        50    0.666667
# 12        51    0.000000
# 13        52    0.303030
# 14        53    0.750000
# 15        54    0.661972
# 16        55    0.742574
# 17        56    0.569444
# 18        57    0.744681
# 19        58    0.807692
# 20        59    0.674419
# 21        60    0.340426
# 22        61    0.521739
# 23        62    0.548387
# 24        63    0.596491
# 25        64    0.857143
# 26        65    0.797468
# 27        66    0.693182
# 28        67    0.764706
# 29        68    0.578947
# 30        69    0.770115
# 31        70    0.778523
# 32        71    0.718750
# 33        72    0.875000
# 34        73    0.774194
# ----------

# %%
#correlation heatmap of dataset
def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

correlation_heatmap(train_data_copy)

# %%
    #COMPARING DEM CLASSIFICATION ALGORITHMS

#Machine Learning Algorithm (MLA) Selection and Initialization
MLA = [
    #Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),
    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBClassifier()    
    ]




#split dataset in cross-validation with this splitter class: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html#sklearn.model_selection.ShuffleSplit
#note: this is an alternative to train_test_split
cv_split = model_selection.ShuffleSplit(n_splits = 10, test_size = .3, train_size = .6, random_state = 0 ) # run model 10x with 60/30 split intentionally leaving out 10%

#create table to compare MLA metrics
MLA_columns = ['MLA Name', 'MLA Parameters','MLA Train Accuracy Mean', 'MLA Test Accuracy Mean', 'MLA Test Accuracy 3*STD' ,'MLA Time']
MLA_compare = pd.DataFrame(columns = MLA_columns)

#create table to compare MLA predictions
MLA_predict = train_data_copy[Target]

#index through MLA and save performance to table
row_index = 0
for alg in MLA:

    #set name and parameters
  MLA_name = alg.__class__.__name__
  MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
  MLA_compare.loc[row_index, 'MLA Parameters'] = str(alg.get_params())
    
    #score model with cross validation: http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html#sklearn.model_selection.cross_validate
  cv_results = model_selection.cross_validate(alg, train_data_copy[train_data_copy_x_bin], train_data_copy[Target], cv  = cv_split)

  MLA_compare.loc[row_index, 'MLA Time'] = cv_results['fit_time'].mean()
  MLA_compare.loc[row_index, 'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
  MLA_compare.loc[row_index, 'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()   
    #if this is a non-bias random sample, then +/-3 standard deviations (std) from the mean, should statistically capture 99.7% of the subsets
  MLA_compare.loc[row_index, 'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3   #let's know the worst that can happen!
    

    #save MLA predictions - see section 6 for usage
  alg.fit(train_data_copy[train_data_copy_x_bin], train_data_copy[Target])
  MLA_predict[MLA_name] = alg.predict(train_data_copy[train_data_copy_x_bin])
    
  row_index+=1

    
#print and sort table: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
MLA_compare.sort_values(by = ['MLA Test Accuracy Mean'], ascending = False, inplace = True)
MLA_compare
#MLA_predict
# Out:
#                      MLA Name  \
# 2        ExtraTreesClassifier
# 5               XGBClassifier
# 3  GradientBoostingClassifier
# 4      RandomForestClassifier
# 0          AdaBoostClassifier
# 1           BaggingClassifier
#
#                                       MLA Parameters MLA Train Accuracy Mean  \
# 2  {'bootstrap': False, 'class_weight': None, 'cr...                0.979818
# 5  {'base_score': 0.5, 'booster': 'gbtree', 'cols...                0.846519
# 3  {'criterion': 'friedman_mse', 'init': None, 'l...                0.860141
# 4  {'bootstrap': True, 'class_weight': None, 'cri...                0.971544
# 0  {'algorithm': 'SAMME.R', 'base_estimator': Non...                 0.80555
# 1  {'base_estimator': None, 'bootstrap': True, 'b...                0.969425
#
#   MLA Test Accuracy Mean MLA Test Accuracy 3*STD   MLA Time
# 2               0.805847               0.0633235  0.0226825
# 5                0.79879               0.0525758  0.0481776
# 3               0.797984               0.0568548   0.116558
# 4               0.791532               0.0443805  0.0199826
# 0               0.786895               0.0659829  0.0940226
# 1               0.785484               0.0493008   0.029104

# %%
#barplot using https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot(x='MLA Test Accuracy Mean', y = 'MLA Name', data = MLA_compare, color = 'm')

#prettify using pyplot: https://matplotlib.org/api/pyplot_api.html
plt.title('Machine Learning Algorithm Accuracy Score \n')
plt.xlabel('Accuracy Score (%)')
plt.ylabel('Algorithm')
# Out:
# Text(0,0.5,'Algorithm')

# %%
#Graph MLA version of Decision Tree: http://scikit-learn.org/stable/modules/generated/sklearn.tree.export_graphviz.html
import graphviz 
dtree = tree.DecisionTreeClassifier(random_state = 0)
dtree.fit(train_data_copy[train_data_copy_x_bin], train_data_copy[Target])
dot_data = tree.export_graphviz(dtree, out_file=None, 
                                feature_names = train_data_copy_x_bin, class_names = True,
                                filled = True, rounded = True)
graph = graphviz.Source(dot_data) 
graph

# %%
#compare algorithm predictions with each other, where 1 = exactly similar and 0 = exactly opposite
#there are some 1's, but enough blues and light reds to create a "super algorithm" by combining them
correlation_heatmap(MLA_predict)

# %%
# prepare data for modeling
print(test_data.info())
print("-"*10)
#test_data.sample(10)

grid_learn = [.01, .03, .05, .1, .25]
grid_n_estimator = [10, 50, 100, 300]
grid_seed = [0]

#extreme boosting w/full dataset modeling submission score: defaults= 0.73684, tuned= 0.77990
submit_xgb = XGBClassifier()
submit_xgb = model_selection.GridSearchCV(XGBClassifier(), param_grid= {'learning_rate': grid_learn, 'max_depth': [0,2,4,6,8,10], 'n_estimators': grid_n_estimator, 'seed': grid_seed}, scoring = 'roc_auc', cv = cv_split)
submit_xgb.fit(train_data_copy[train_data_copy_x_bin], train_data_copy[Target])
print('Best Parameters: ', submit_xgb.best_params_) #Best Parameters:  {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'seed': 0}
test_data['WnvPresent'] = submit_xgb.predict(test_data[train_data_copy_x_bin])

#submit file
submit = test_data[['Id','WnvPresent']]
submit.to_csv("./submit.csv", index=False)

print('Validation Data Distribution: \n', test_data['WnvPresent'].value_counts(normalize = True))
submit.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 232586 entries, 0 to 232585
# Data columns (total 45 columns):
# Id                        232586 non-null int64
# Date                      232586 non-null object
# Address                   232586 non-null object
# Species                   232586 non-null object
# Block                     232586 non-null int64
# Street                    232586 non-null object
# Trap                      232586 non-null object
# AddressNumberAndStreet    232586 non-null object
# Latitude                  232586 non-null float64
# Longitude                 232586 non-null float64
# AddressAccuracy           232586 non-null int64
# Species_Code              232586 non-null int64
# LatBin                    232586 non-null category
# LatBin_Code               232586 non-null int64
# LongBin                   232586 non-null category
# LongBin_Code              232586 non-null int64
# AddressNum                232586 non-null int64
# AddressNumBin             232586 non-null category
# AddressNumBin_Code        232586 non-null int64
# Year                      232586 non-null int64
# Month                     232586 non-null int64
# TrapNum                   211256 non-null float64
# TrapNumBin                211256 non-null category
# TrapNumBin_Code           232586 non-null int64
# Station                   232586 non-null int64
# Tmax                      232586 non-null int64
# Tmin                      232586 non-null int64
# Tavg                      232586 non-null object
# Depart                    232586 non-null object
# DewPoint                  232586 non-null int64
# WetBulb                   232586 non-null object
# Heat                      232586 non-null object
# Cool                      232586 non-null object
# Sunrise                   232586 non-null object
# Sunset                    232586 non-null object
# CodeSum                   232586 non-null object
# Depth                     232586 non-null object
# Water1                    232586 non-null object
# SnowFall                  232586 non-null object
# PrecipTotal               232586 non-null object
# StnPressure               232586 non-null object
# SeaLevel                  232586 non-null object
# ResultSpeed               232586 non-null float64
# ResultDir                 232586 non-null int64
# AvgSpeed                  232586 non-null object
# dtypes: category(4), float64(4), int64(16), object(21)
# memory usage: 75.4+ MB
# None
# ----------
# Best Parameters:  {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 300, 'seed': 0}
# Validation Data Distribution:
#  0    0.832548
# 1    0.167452
# Name: WnvPresent, dtype: float64
#             Id  WnvPresent
# 137084   68543           0
# 145758   72880           1
# 86513    43257           0
# 41019    20510           1
# 36087    18044           0
# 191333   95667           0
# 193574   96788           0
# 103743   51872           0
# 57054    28528           0
# 229874  114938           0
